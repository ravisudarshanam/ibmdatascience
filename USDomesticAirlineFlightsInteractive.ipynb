# %%
pip install jupyter_dashboards
# Out:
# Requirement already satisfied: jupyter_dashboards in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (0.7.0)
# Requirement already satisfied: notebook>=4.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter_dashboards) (6.4.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (6.1)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (20.0.0)
# Requirement already satisfied: ipykernel in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (6.4.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (4.7.1)
# Requirement already satisfied: traitlets>=4.2.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (5.0.5)
# Requirement already satisfied: prometheus-client in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (0.11.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (6.1.12)
# Requirement already satisfied: Send2Trash>=1.5.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (1.5.0)
# Requirement already satisfied: nbformat in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (5.1.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (0.9.4)
# Requirement already satisfied: nbconvert in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (6.0.7)
# Requirement already satisfied: ipython-genutils in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (0.2.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (20.1.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook>=4.0->jupyter_dashboards) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_dashboards) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from python-dateutil>=2.1->jupyter-client>=5.3.4->notebook>=4.0->jupyter_dashboards) (1.15.0)
# Requirement already satisfied: ptyprocess in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_dashboards) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.0->jupyter_dashboards) (1.14.5)
# Requirement already satisfied: pycparser in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0->jupyter_dashboards) (2.20)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_dashboards) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_dashboards) (1.4.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_dashboards) (7.27.0)
# Requirement already satisfied: pickleshare in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (4.8.0)
# Requirement already satisfied: backcall in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (52.0.0.post20211006)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (3.0.20)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (5.0.9)
# Requirement already satisfied: pygments in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (2.9.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->notebook>=4.0->jupyter_dashboards) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jinja2->notebook>=4.0->jupyter_dashboards) (2.0.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.1.2)
# Requirement already satisfied: testpath in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.3)
# Requirement already satisfied: defusedxml in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.7.1)
# Requirement already satisfied: bleach in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (3.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->jupyter_dashboards) (1.4.3)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0->jupyter_dashboards) (1.5.1)
# Requirement already satisfied: async-generator in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0->jupyter_dashboards) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbformat->notebook>=4.0->jupyter_dashboards) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_dashboards) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_dashboards) (0.17.3)
# Requirement already satisfied: webencodings in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.0->jupyter_dashboards) (0.5.1)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.0->jupyter_dashboards) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.0->jupyter_dashboards) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update


# Create a dash application
app = JupyterDash(__name__)
JupyterDash.infer_jupyter_proxy_config()

# REVIEW1: Clear the layout and do not display exception till callback gets executed
app.config.suppress_callback_exceptions = True

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})


# List of years 
year_list = [i for i in range(2005, 2021, 1)]

"""Compute graph data for creating yearly airline performance report 

Function that takes airline data as input and create 5 dataframes based on the grouping condition to be used for plottling charts and grphs.

Argument:
     
    df: Filtered dataframe
    
Returns:
   Dataframes to create graph. 
"""
def compute_data_choice_1(df):
    # Cancellation Category Count
    bar_data = df.groupby(['Month','CancellationCode'])['Flights'].sum().reset_index()
    # Average flight time by reporting airline
    line_data = df.groupby(['Month','Reporting_Airline'])['AirTime'].mean().reset_index()
    # Diverted Airport Landings
    div_data = df[df['DivAirportLandings'] != 0.0]
    # Source state count
    map_data = df.groupby(['OriginState'])['Flights'].sum().reset_index()
    # Destination state count
    tree_data = df.groupby(['DestState', 'Reporting_Airline'])['Flights'].sum().reset_index()
    return bar_data, line_data, div_data, map_data, tree_data


"""Compute graph data for creating yearly airline delay report

This function takes in airline data and selected year as an input and performs computation for creating charts and plots.

Arguments:
    df: Input airline data.
    
Returns:
    Computed average dataframes for carrier delay, weather delay, NAS delay, security delay, and late aircraft delay.
"""
def compute_data_choice_2(df):
    # Compute delay averages
    avg_car = df.groupby(['Month','Reporting_Airline'])['CarrierDelay'].mean().reset_index()
    avg_weather = df.groupby(['Month','Reporting_Airline'])['WeatherDelay'].mean().reset_index()
    avg_NAS = df.groupby(['Month','Reporting_Airline'])['NASDelay'].mean().reset_index()
    avg_sec = df.groupby(['Month','Reporting_Airline'])['SecurityDelay'].mean().reset_index()
    avg_late = df.groupby(['Month','Reporting_Airline'])['LateAircraftDelay'].mean().reset_index()
    return avg_car, avg_weather, avg_NAS, avg_sec, avg_late


# Application layout
app.layout = html.Div(children=[ 
                                # TODO1: Add title to the dashboard
                               html.H1('US Domestic Airline Flights Performance',
                                    style = {'textAlign': 'center','color' : '#503D36','font-size': 24}), 
    
                                # REVIEW2: Dropdown creation
                                # Create an outer division 
                                html.Div([
                                    # Add an division
                                    html.Div([
                                        # Create an division for adding dropdown helper text for report type
                                        html.Div(
                                            [
                                            html.H2('Report Type:', style={'margin-right': '2em'}),
                                            ]
                                        ),
                                        # TODO2: Add a dropdown
                                        dcc.Dropdown(id='input-type',
                                                    options=[
                                                            {'label': 'Yearly Airline Performance Report', 'value': 'OPT1'},
                                                            {'label': 'Yearly Airline Delay Report', 'value': 'OPT2'}],
                                                    placeholder='Select a report type',
                                                    style={'width':'80%','padding':'3px','font-size':'20px','text-align':'center'}),
                                    # Place them next to each other using the division style
                                    ], style={'display':'flex'}),
                                    
                                   # Add next division 
                                   html.Div([
                                       # Create an division for adding dropdown helper text for choosing year
                                        html.Div(
                                            [
                                            html.H2('Choose Year:', style={'margin-right': '2em'})
                                            ]
                                        ),
                                        dcc.Dropdown(id='input-year', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': i, 'value': i} for i in year_list],
                                                     placeholder="Select a year",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}),
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}),  
                                          ]),
                                
                                # Add Computed graphs
                                # REVIEW3: Observe how we add an empty division and providing an id that will be updated during callback
                                html.Div([ ], id='plot1'),
    
                                html.Div([
                                        html.Div([ ], id='plot2'),
                                        html.Div([ ], id='plot3')
                                ], style={'display': 'flex'}),
                                
                                # TODO3: Add a division with two empty divisions inside. See above disvision for example.
                               html.Div([
                                   html.Div([ ], id='plot4'),
                                   html.Div([ ], id='plot5')], 
                                style={'display': 'flex'}),
                                ])





# Callback function definition
# TODO4: Add 5 ouput components
@app.callback([Output(component_id='plot1', component_property='children'),
               Output(component_id='plot2', component_property='children'),
               Output(component_id='plot3', component_property='children'),
               Output(component_id='plot4', component_property='children'),
               Output(component_id='plot5', component_property='children')],
               [Input(component_id='input-type', component_property='value'),
                Input(component_id='input-year', component_property='value')],
               # REVIEW4: Holding output state till user enters all the form information. In this case, it will be chart type and year
               [State("plot1", 'children'), State("plot2", "children"),
                State("plot3", "children"), State("plot4", "children"),
                State("plot5", "children")
               ])
# Add computation to callback function and return graph
def get_graph(chart, year, children1, children2, c3, c4, c5):
      
        # Select data
        df =  airline_data[airline_data['Year']==int(year)]
       
        if chart == 'OPT1':
            # Compute required information for creating graph from the data
            bar_data, line_data, div_data, map_data, tree_data = compute_data_choice_1(df)
            
            # Number of flights under different cancellation categories
            bar_fig = px.bar(bar_data, x='Month', y='Flights', color='CancellationCode', title='Monthly Flight Cancellation')
            
            # TODO5: Average flight time by reporting airline
            line_fig = px.line(line_data, x='Month', y='AirTime', color='Reporting_Airline', title='Average monthly flight time (minutes) by airline')
            
            # Percentage of diverted airport landings per reporting airline
            pie_fig = px.pie(div_data, values='Flights', names='Reporting_Airline', title='% of flights by reporting airline')
            
            # REVIEW5: Number of flights flying from each state using choropleth
            map_fig = px.choropleth(map_data,  # Input data
                    locations='OriginState', 
                    color='Flights',  
                    hover_data=['OriginState', 'Flights'], 
                    locationmode = 'USA-states', # Set to plot as US States
                    color_continuous_scale='GnBu',
                    range_color=[0, map_data['Flights'].max()]) 
            map_fig.update_layout(
                    title_text = 'Number of flights from origin state', 
                    geo_scope='usa') # Plot only the USA instead of globe
            
            # TODO6: Number of flights flying to each state from each reporting airline
            tree_fig = px.treemap(tree_data, path=['DestState', 'Reporting_Airline'],
                         values='Flights',
                                  color='Flights',
                                  color_continuous_scale='RdBu',
                                  title='Flight count by airline to destination state'
                                 )
            
            
            # REVIEW6: Return dcc.Graph component to the empty division
            return [dcc.Graph(figure=tree_fig), 
                    dcc.Graph(figure=pie_fig),
                    dcc.Graph(figure=map_fig),
                    dcc.Graph(figure=bar_fig),
                    dcc.Graph(figure=line_fig)
                   ]
        else:
            # REVIEW7: This covers chart type 2 and we have completed this exercise under Flight Delay Time Statistics Dashboard section
            # Compute required information for creating graph from the data
            avg_car, avg_weather, avg_NAS, avg_sec, avg_late = compute_data_choice_2(df)
            
            # Create graph
            carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')
            weather_fig = px.line(avg_weather, x='Month', y='WeatherDelay', color='Reporting_Airline', title='Average weather delay time (minutes) by airline')
            nas_fig = px.line(avg_NAS, x='Month', y='NASDelay', color='Reporting_Airline', title='Average NAS delay time (minutes) by airline')
            sec_fig = px.line(avg_sec, x='Month', y='SecurityDelay', color='Reporting_Airline', title='Average security delay time (minutes) by airline')
            late_fig = px.line(avg_late, x='Month', y='LateAircraftDelay', color='Reporting_Airline', title='Average late aircraft delay time (minutes) by airline')
            
            return[dcc.Graph(figure=carrier_fig), 
                   dcc.Graph(figure=weather_fig), 
                   dcc.Graph(figure=nas_fig), 
                   dcc.Graph(figure=sec_fig), 
                   dcc.Graph(figure=late_fig)]


# Run the app
if __name__ == '__main__':
    # REVIEW8: Adding dev_tools_ui=False, dev_tools_props_check=False can prevent error appearing before calling callback function
    app.run_server(mode="inline", host="localhost", debug=False, dev_tools_ui=False, dev_tools_props_check=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/wsuser/ipykernel_213/3675041694.py in <module>
#       1 # Import required libraries
#       2 import pandas as pd
# ----> 3 import dash
#       4 import dash_html_components as html
#       5 import dash_core_components as dcc
#
# ModuleNotFoundError: No module named 'dash'

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update


# Create a dash application
app = JupyterDash(__name__)
JupyterDash.infer_jupyter_proxy_config()

# REVIEW1: Clear the layout and do not display exception till callback gets executed
app.config.suppress_callback_exceptions = True

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})


# List of years 
year_list = [i for i in range(2005, 2021, 1)]

"""Compute graph data for creating yearly airline performance report 

Function that takes airline data as input and create 5 dataframes based on the grouping condition to be used for plottling charts and grphs.

Argument:
     
    df: Filtered dataframe
    
Returns:
   Dataframes to create graph. 
"""
def compute_data_choice_1(df):
    # Cancellation Category Count
    bar_data = df.groupby(['Month','CancellationCode'])['Flights'].sum().reset_index()
    # Average flight time by reporting airline
    line_data = df.groupby(['Month','Reporting_Airline'])['AirTime'].mean().reset_index()
    # Diverted Airport Landings
    div_data = df[df['DivAirportLandings'] != 0.0]
    # Source state count
    map_data = df.groupby(['OriginState'])['Flights'].sum().reset_index()
    # Destination state count
    tree_data = df.groupby(['DestState', 'Reporting_Airline'])['Flights'].sum().reset_index()
    return bar_data, line_data, div_data, map_data, tree_data


"""Compute graph data for creating yearly airline delay report

This function takes in airline data and selected year as an input and performs computation for creating charts and plots.

Arguments:
    df: Input airline data.
    
Returns:
    Computed average dataframes for carrier delay, weather delay, NAS delay, security delay, and late aircraft delay.
"""
def compute_data_choice_2(df):
    # Compute delay averages
    avg_car = df.groupby(['Month','Reporting_Airline'])['CarrierDelay'].mean().reset_index()
    avg_weather = df.groupby(['Month','Reporting_Airline'])['WeatherDelay'].mean().reset_index()
    avg_NAS = df.groupby(['Month','Reporting_Airline'])['NASDelay'].mean().reset_index()
    avg_sec = df.groupby(['Month','Reporting_Airline'])['SecurityDelay'].mean().reset_index()
    avg_late = df.groupby(['Month','Reporting_Airline'])['LateAircraftDelay'].mean().reset_index()
    return avg_car, avg_weather, avg_NAS, avg_sec, avg_late


# Application layout
app.layout = html.Div(children=[ 
                                # TODO1: Add title to the dashboard
                               html.H1('US Domestic Airline Flights Performance',
                                    style = {'textAlign': 'center','color' : '#503D36','font-size': 24}), 
    
                                # REVIEW2: Dropdown creation
                                # Create an outer division 
                                html.Div([
                                    # Add an division
                                    html.Div([
                                        # Create an division for adding dropdown helper text for report type
                                        html.Div(
                                            [
                                            html.H2('Report Type:', style={'margin-right': '2em'}),
                                            ]
                                        ),
                                        # TODO2: Add a dropdown
                                        dcc.Dropdown(id='input-type',
                                                    options=[
                                                            {'label': 'Yearly Airline Performance Report', 'value': 'OPT1'},
                                                            {'label': 'Yearly Airline Delay Report', 'value': 'OPT2'}],
                                                    placeholder='Select a report type',
                                                    style={'width':'80%','padding':'3px','font-size':'20px','text-align':'center'}),
                                    # Place them next to each other using the division style
                                    ], style={'display':'flex'}),
                                    
                                   # Add next division 
                                   html.Div([
                                       # Create an division for adding dropdown helper text for choosing year
                                        html.Div(
                                            [
                                            html.H2('Choose Year:', style={'margin-right': '2em'})
                                            ]
                                        ),
                                        dcc.Dropdown(id='input-year', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': i, 'value': i} for i in year_list],
                                                     placeholder="Select a year",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}),
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}),  
                                          ]),
                                
                                # Add Computed graphs
                                # REVIEW3: Observe how we add an empty division and providing an id that will be updated during callback
                                html.Div([ ], id='plot1'),
    
                                html.Div([
                                        html.Div([ ], id='plot2'),
                                        html.Div([ ], id='plot3')
                                ], style={'display': 'flex'}),
                                
                                # TODO3: Add a division with two empty divisions inside. See above disvision for example.
                               html.Div([
                                   html.Div([ ], id='plot4'),
                                   html.Div([ ], id='plot5')], 
                                style={'display': 'flex'}),
                                ])





# Callback function definition
# TODO4: Add 5 ouput components
@app.callback([Output(component_id='plot1', component_property='children'),
               Output(component_id='plot2', component_property='children'),
               Output(component_id='plot3', component_property='children'),
               Output(component_id='plot4', component_property='children'),
               Output(component_id='plot5', component_property='children')],
               [Input(component_id='input-type', component_property='value'),
                Input(component_id='input-year', component_property='value')],
               # REVIEW4: Holding output state till user enters all the form information. In this case, it will be chart type and year
               [State("plot1", 'children'), State("plot2", "children"),
                State("plot3", "children"), State("plot4", "children"),
                State("plot5", "children")
               ])
# Add computation to callback function and return graph
def get_graph(chart, year, children1, children2, c3, c4, c5):
      
        # Select data
        df =  airline_data[airline_data['Year']==int(year)]
       
        if chart == 'OPT1':
            # Compute required information for creating graph from the data
            bar_data, line_data, div_data, map_data, tree_data = compute_data_choice_1(df)
            
            # Number of flights under different cancellation categories
            bar_fig = px.bar(bar_data, x='Month', y='Flights', color='CancellationCode', title='Monthly Flight Cancellation')
            
            # TODO5: Average flight time by reporting airline
            line_fig = px.line(line_data, x='Month', y='AirTime', color='Reporting_Airline', title='Average monthly flight time (minutes) by airline')
            
            # Percentage of diverted airport landings per reporting airline
            pie_fig = px.pie(div_data, values='Flights', names='Reporting_Airline', title='% of flights by reporting airline')
            
            # REVIEW5: Number of flights flying from each state using choropleth
            map_fig = px.choropleth(map_data,  # Input data
                    locations='OriginState', 
                    color='Flights',  
                    hover_data=['OriginState', 'Flights'], 
                    locationmode = 'USA-states', # Set to plot as US States
                    color_continuous_scale='GnBu',
                    range_color=[0, map_data['Flights'].max()]) 
            map_fig.update_layout(
                    title_text = 'Number of flights from origin state', 
                    geo_scope='usa') # Plot only the USA instead of globe
            
            # TODO6: Number of flights flying to each state from each reporting airline
            tree_fig = px.treemap(tree_data, path=['DestState', 'Reporting_Airline'],
                         values='Flights',
                                  color='Flights',
                                  color_continuous_scale='RdBu',
                                  title='Flight count by airline to destination state'
                                 )
            
            
            # REVIEW6: Return dcc.Graph component to the empty division
            return [dcc.Graph(figure=tree_fig), 
                    dcc.Graph(figure=pie_fig),
                    dcc.Graph(figure=map_fig),
                    dcc.Graph(figure=bar_fig),
                    dcc.Graph(figure=line_fig)
                   ]
        else:
            # REVIEW7: This covers chart type 2 and we have completed this exercise under Flight Delay Time Statistics Dashboard section
            # Compute required information for creating graph from the data
            avg_car, avg_weather, avg_NAS, avg_sec, avg_late = compute_data_choice_2(df)
            
            # Create graph
            carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')
            weather_fig = px.line(avg_weather, x='Month', y='WeatherDelay', color='Reporting_Airline', title='Average weather delay time (minutes) by airline')
            nas_fig = px.line(avg_NAS, x='Month', y='NASDelay', color='Reporting_Airline', title='Average NAS delay time (minutes) by airline')
            sec_fig = px.line(avg_sec, x='Month', y='SecurityDelay', color='Reporting_Airline', title='Average security delay time (minutes) by airline')
            late_fig = px.line(avg_late, x='Month', y='LateAircraftDelay', color='Reporting_Airline', title='Average late aircraft delay time (minutes) by airline')
            
            return[dcc.Graph(figure=carrier_fig), 
                   dcc.Graph(figure=weather_fig), 
                   dcc.Graph(figure=nas_fig), 
                   dcc.Graph(figure=sec_fig), 
                   dcc.Graph(figure=late_fig)]


# Run the app
if __name__ == '__main__':
    # REVIEW8: Adding dev_tools_ui=False, dev_tools_props_check=False can prevent error appearing before calling callback function
    app.run_server(mode="inline", host="localhost", debug=False, dev_tools_ui=False, dev_tools_props_check=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/wsuser/ipykernel_461/3675041694.py in <module>
#       5 import dash_core_components as dcc
#       6 from dash.dependencies import Input, Output, State
# ----> 7 from jupyter_dash import JupyterDash
#       8 import plotly.graph_objects as go
#       9 import plotly.express as px
#
# ModuleNotFoundError: No module named 'jupyter_dash'

# %%
conda install jupyter_dashboards -c conda-forge
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update


# Create a dash application
app = JupyterDash(__name__)
JupyterDash.infer_jupyter_proxy_config()

# REVIEW1: Clear the layout and do not display exception till callback gets executed
app.config.suppress_callback_exceptions = True

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})


# List of years 
year_list = [i for i in range(2005, 2021, 1)]

"""Compute graph data for creating yearly airline performance report 

Function that takes airline data as input and create 5 dataframes based on the grouping condition to be used for plottling charts and grphs.

Argument:
     
    df: Filtered dataframe
    
Returns:
   Dataframes to create graph. 
"""
def compute_data_choice_1(df):
    # Cancellation Category Count
    bar_data = df.groupby(['Month','CancellationCode'])['Flights'].sum().reset_index()
    # Average flight time by reporting airline
    line_data = df.groupby(['Month','Reporting_Airline'])['AirTime'].mean().reset_index()
    # Diverted Airport Landings
    div_data = df[df['DivAirportLandings'] != 0.0]
    # Source state count
    map_data = df.groupby(['OriginState'])['Flights'].sum().reset_index()
    # Destination state count
    tree_data = df.groupby(['DestState', 'Reporting_Airline'])['Flights'].sum().reset_index()
    return bar_data, line_data, div_data, map_data, tree_data


"""Compute graph data for creating yearly airline delay report

This function takes in airline data and selected year as an input and performs computation for creating charts and plots.

Arguments:
    df: Input airline data.
    
Returns:
    Computed average dataframes for carrier delay, weather delay, NAS delay, security delay, and late aircraft delay.
"""
def compute_data_choice_2(df):
    # Compute delay averages
    avg_car = df.groupby(['Month','Reporting_Airline'])['CarrierDelay'].mean().reset_index()
    avg_weather = df.groupby(['Month','Reporting_Airline'])['WeatherDelay'].mean().reset_index()
    avg_NAS = df.groupby(['Month','Reporting_Airline'])['NASDelay'].mean().reset_index()
    avg_sec = df.groupby(['Month','Reporting_Airline'])['SecurityDelay'].mean().reset_index()
    avg_late = df.groupby(['Month','Reporting_Airline'])['LateAircraftDelay'].mean().reset_index()
    return avg_car, avg_weather, avg_NAS, avg_sec, avg_late


# Application layout
app.layout = html.Div(children=[ 
                                # TODO1: Add title to the dashboard
                               html.H1('US Domestic Airline Flights Performance',
                                    style = {'textAlign': 'center','color' : '#503D36','font-size': 24}), 
    
                                # REVIEW2: Dropdown creation
                                # Create an outer division 
                                html.Div([
                                    # Add an division
                                    html.Div([
                                        # Create an division for adding dropdown helper text for report type
                                        html.Div(
                                            [
                                            html.H2('Report Type:', style={'margin-right': '2em'}),
                                            ]
                                        ),
                                        # TODO2: Add a dropdown
                                        dcc.Dropdown(id='input-type',
                                                    options=[
                                                            {'label': 'Yearly Airline Performance Report', 'value': 'OPT1'},
                                                            {'label': 'Yearly Airline Delay Report', 'value': 'OPT2'}],
                                                    placeholder='Select a report type',
                                                    style={'width':'80%','padding':'3px','font-size':'20px','text-align':'center'}),
                                    # Place them next to each other using the division style
                                    ], style={'display':'flex'}),
                                    
                                   # Add next division 
                                   html.Div([
                                       # Create an division for adding dropdown helper text for choosing year
                                        html.Div(
                                            [
                                            html.H2('Choose Year:', style={'margin-right': '2em'})
                                            ]
                                        ),
                                        dcc.Dropdown(id='input-year', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': i, 'value': i} for i in year_list],
                                                     placeholder="Select a year",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}),
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}),  
                                          ]),
                                
                                # Add Computed graphs
                                # REVIEW3: Observe how we add an empty division and providing an id that will be updated during callback
                                html.Div([ ], id='plot1'),
    
                                html.Div([
                                        html.Div([ ], id='plot2'),
                                        html.Div([ ], id='plot3')
                                ], style={'display': 'flex'}),
                                
                                # TODO3: Add a division with two empty divisions inside. See above disvision for example.
                               html.Div([
                                   html.Div([ ], id='plot4'),
                                   html.Div([ ], id='plot5')], 
                                style={'display': 'flex'}),
                                ])





# Callback function definition
# TODO4: Add 5 ouput components
@app.callback([Output(component_id='plot1', component_property='children'),
               Output(component_id='plot2', component_property='children'),
               Output(component_id='plot3', component_property='children'),
               Output(component_id='plot4', component_property='children'),
               Output(component_id='plot5', component_property='children')],
               [Input(component_id='input-type', component_property='value'),
                Input(component_id='input-year', component_property='value')],
               # REVIEW4: Holding output state till user enters all the form information. In this case, it will be chart type and year
               [State("plot1", 'children'), State("plot2", "children"),
                State("plot3", "children"), State("plot4", "children"),
                State("plot5", "children")
               ])
# Add computation to callback function and return graph
def get_graph(chart, year, children1, children2, c3, c4, c5):
      
        # Select data
        df =  airline_data[airline_data['Year']==int(year)]
       
        if chart == 'OPT1':
            # Compute required information for creating graph from the data
            bar_data, line_data, div_data, map_data, tree_data = compute_data_choice_1(df)
            
            # Number of flights under different cancellation categories
            bar_fig = px.bar(bar_data, x='Month', y='Flights', color='CancellationCode', title='Monthly Flight Cancellation')
            
            # TODO5: Average flight time by reporting airline
            line_fig = px.line(line_data, x='Month', y='AirTime', color='Reporting_Airline', title='Average monthly flight time (minutes) by airline')
            
            # Percentage of diverted airport landings per reporting airline
            pie_fig = px.pie(div_data, values='Flights', names='Reporting_Airline', title='% of flights by reporting airline')
            
            # REVIEW5: Number of flights flying from each state using choropleth
            map_fig = px.choropleth(map_data,  # Input data
                    locations='OriginState', 
                    color='Flights',  
                    hover_data=['OriginState', 'Flights'], 
                    locationmode = 'USA-states', # Set to plot as US States
                    color_continuous_scale='GnBu',
                    range_color=[0, map_data['Flights'].max()]) 
            map_fig.update_layout(
                    title_text = 'Number of flights from origin state', 
                    geo_scope='usa') # Plot only the USA instead of globe
            
            # TODO6: Number of flights flying to each state from each reporting airline
            tree_fig = px.treemap(tree_data, path=['DestState', 'Reporting_Airline'],
                         values='Flights',
                                  color='Flights',
                                  color_continuous_scale='RdBu',
                                  title='Flight count by airline to destination state'
                                 )
            
            
            # REVIEW6: Return dcc.Graph component to the empty division
            return [dcc.Graph(figure=tree_fig), 
                    dcc.Graph(figure=pie_fig),
                    dcc.Graph(figure=map_fig),
                    dcc.Graph(figure=bar_fig),
                    dcc.Graph(figure=line_fig)
                   ]
        else:
            # REVIEW7: This covers chart type 2 and we have completed this exercise under Flight Delay Time Statistics Dashboard section
            # Compute required information for creating graph from the data
            avg_car, avg_weather, avg_NAS, avg_sec, avg_late = compute_data_choice_2(df)
            
            # Create graph
            carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')
            weather_fig = px.line(avg_weather, x='Month', y='WeatherDelay', color='Reporting_Airline', title='Average weather delay time (minutes) by airline')
            nas_fig = px.line(avg_NAS, x='Month', y='NASDelay', color='Reporting_Airline', title='Average NAS delay time (minutes) by airline')
            sec_fig = px.line(avg_sec, x='Month', y='SecurityDelay', color='Reporting_Airline', title='Average security delay time (minutes) by airline')
            late_fig = px.line(avg_late, x='Month', y='LateAircraftDelay', color='Reporting_Airline', title='Average late aircraft delay time (minutes) by airline')
            
            return[dcc.Graph(figure=carrier_fig), 
                   dcc.Graph(figure=weather_fig), 
                   dcc.Graph(figure=nas_fig), 
                   dcc.Graph(figure=sec_fig), 
                   dcc.Graph(figure=late_fig)]


# Run the app
if __name__ == '__main__':
    # REVIEW8: Adding dev_tools_ui=False, dev_tools_props_check=False can prevent error appearing before calling callback function
    app.run_server(mode="inline", host="localhost", debug=False, dev_tools_ui=False, dev_tools_props_check=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/wsuser/ipykernel_461/3675041694.py in <module>
#       5 import dash_core_components as dcc
#       6 from dash.dependencies import Input, Output, State
# ----> 7 from jupyter_dash import JupyterDash
#       8 import plotly.graph_objects as go
#       9 import plotly.express as px
#
# ModuleNotFoundError: No module named 'jupyter_dash'

# %%
python -m pip install -e .
# Out:
#   File "/tmp/wsuser/ipykernel_461/2516302337.py", line 1
#     python -m pip install -e .
#               ^
# SyntaxError: invalid syntax

# %%
pip install jupyter-plotly-dash
# Out:
# Requirement already satisfied: jupyter-plotly-dash in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (0.4.3)
# Requirement already satisfied: django-bootstrap4 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-plotly-dash) (21.2)
# Requirement already satisfied: django-plotly-dash in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-plotly-dash) (1.6.6)
# Requirement already satisfied: jupyter in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-plotly-dash) (1.0.0)
# Requirement already satisfied: aiohttp in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-plotly-dash) (3.8.1)
# Requirement already satisfied: dpd-static-support in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-plotly-dash) (0.0.5)
# Requirement already satisfied: dpd-components in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-plotly-dash) (0.1.0)
# Requirement already satisfied: nbserverproxy in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-plotly-dash) (0.8.8)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (4.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (1.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (5.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (21.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from aiohttp->jupyter-plotly-dash) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->jupyter-plotly-dash) (3.7.4.3)
# Requirement already satisfied: idna>=2.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter-plotly-dash) (2.8)
# Requirement already satisfied: Django>=2.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from django-bootstrap4->jupyter-plotly-dash) (4.0.2)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from django-bootstrap4->jupyter-plotly-dash) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from beautifulsoup4>=4.8.0->django-bootstrap4->jupyter-plotly-dash) (2.2.1)
# Requirement already satisfied: backports.zoneinfo in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from Django>=2.2->django-bootstrap4->jupyter-plotly-dash) (0.2.1)
# Requirement already satisfied: asgiref<4,>=3.4.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from Django>=2.2->django-bootstrap4->jupyter-plotly-dash) (3.5.0)
# Requirement already satisfied: sqlparse>=0.2.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from Django>=2.2->django-bootstrap4->jupyter-plotly-dash) (0.4.2)
# Requirement already satisfied: dash-core-components in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (1.16.0)
# Requirement already satisfied: Flask>=1.0.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (2.0.2)
# Requirement already satisfied: dash<1.21.0,>=1.11 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (1.20.0)
# Requirement already satisfied: dash-renderer in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (1.9.1)
# Requirement already satisfied: dash-html-components in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (1.1.3)
# Requirement already satisfied: plotly in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from django-plotly-dash->jupyter-plotly-dash) (4.14.3)
# Requirement already satisfied: dash-table==4.11.3 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from dash<1.21.0,>=1.11->django-plotly-dash->jupyter-plotly-dash) (4.11.3)
# Requirement already satisfied: future in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from dash<1.21.0,>=1.11->django-plotly-dash->jupyter-plotly-dash) (0.18.2)
# Requirement already satisfied: flask-compress in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from dash<1.21.0,>=1.11->django-plotly-dash->jupyter-plotly-dash) (1.10.1)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (3.0.0)
# Requirement already satisfied: Werkzeug>=2.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (2.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from Jinja2>=3.0->Flask>=1.0.2->django-plotly-dash->jupyter-plotly-dash) (2.0.1)
# Requirement already satisfied: brotli in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from flask-compress->dash<1.21.0,>=1.11->django-plotly-dash->jupyter-plotly-dash) (1.0.9)
# Requirement already satisfied: ipywidgets in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (7.6.3)
# Requirement already satisfied: ipykernel in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (6.4.1)
# Requirement already satisfied: nbconvert in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (6.0.7)
# Requirement already satisfied: qtconsole in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (5.2.2)
# Requirement already satisfied: jupyter-console in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (6.4.0)
# Requirement already satisfied: notebook in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter->jupyter-plotly-dash) (6.4.0)
# Requirement already satisfied: jupyter-client<8.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (1.4.1)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (5.0.5)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (7.27.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipykernel->jupyter->jupyter-plotly-dash) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (0.17.2)
# Requirement already satisfied: pickleshare in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (0.7.5)
# Requirement already satisfied: backcall in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (0.2.0)
# Requirement already satisfied: pygments in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (2.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (3.0.20)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (5.0.9)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (52.0.0.post20211006)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (0.7.0)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter->jupyter-plotly-dash) (20.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter->jupyter-plotly-dash) (2.8.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel->jupyter->jupyter-plotly-dash) (4.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->jupyter->jupyter-plotly-dash) (0.2.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter->jupyter-plotly-dash) (1.15.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipywidgets->jupyter->jupyter-plotly-dash) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipywidgets->jupyter->jupyter-plotly-dash) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from ipywidgets->jupyter->jupyter-plotly-dash) (5.1.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->jupyter-plotly-dash) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->jupyter-plotly-dash) (0.17.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook->jupyter->jupyter-plotly-dash) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook->jupyter->jupyter-plotly-dash) (0.9.4)
# Requirement already satisfied: prometheus-client in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook->jupyter->jupyter-plotly-dash) (0.11.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from notebook->jupyter->jupyter-plotly-dash) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter->jupyter-plotly-dash) (1.14.5)
# Requirement already satisfied: pycparser in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->jupyter-plotly-dash) (2.20)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.5.3)
# Requirement already satisfied: bleach in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (3.3.0)
# Requirement already satisfied: testpath in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.4.4)
# Requirement already satisfied: defusedxml in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbconvert->jupyter->jupyter-plotly-dash) (0.3)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter-plotly-dash) (1.5.1)
# Requirement already satisfied: async-generator in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter-plotly-dash) (1.10)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->jupyter-plotly-dash) (20.9)
# Requirement already satisfied: webencodings in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from bleach->nbconvert->jupyter->jupyter-plotly-dash) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from packaging->bleach->nbconvert->jupyter->jupyter-plotly-dash) (2.4.7)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from plotly->django-plotly-dash->jupyter-plotly-dash) (1.3.3)
# Requirement already satisfied: qtpy in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from qtconsole->jupyter->jupyter-plotly-dash) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/wsuser/ipykernel_461/1165061568.py in <module>
#       4 import dash_core_components as dcc
#       5 from dash.dependencies import Input, Output, State
# ----> 6 from jupyter_dash import JupyterDash
#       7 import plotly.graph_objects as go
#       8 import plotly.express as px
#
# ModuleNotFoundError: No module named 'jupyter_dash'

# %%
conda install -c plotly jupyter-dash
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python-3.8-main
#
#   added / updated specs:
#     - jupyter-dash
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ansi2html-1.5.2            |   py38h06a4308_0         265 KB
#     dash-0.39.0                |             py_0          39 KB  plotly
#     dash-core-components-0.44.0|             py_0         3.4 MB  plotly
#     dash-html-components-0.14.0|             py_0         345 KB  plotly
#     dash-renderer-0.20.0       |             py_0         743 KB  plotly
#     dash-table-3.6.0           |             py_0         410 KB  plotly
#     flask-2.0.2                |     pyhd3eb1b0_0          78 KB
#     flask-compress-1.4.0       |             py_0           6 KB  plotly
#     itsdangerous-2.0.1         |     pyhd3eb1b0_0          18 KB
#     jupyter-dash-0.3.0         |             py_0          49 KB  plotly
#     ------------------------------------------------------------
#                                            Total:         5.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   ansi2html          pkgs/main/linux-64::ansi2html-1.5.2-py38h06a4308_0
#   dash               plotly/noarch::dash-0.39.0-py_0
#   dash-core-compone~ plotly/noarch::dash-core-components-0.44.0-py_0
#   dash-html-compone~ plotly/noarch::dash-html-components-0.14.0-py_0
#   dash-renderer      plotly/noarch::dash-renderer-0.20.0-py_0
#   dash-table         plotly/noarch::dash-table-3.6.0-py_0
#   flask              pkgs/main/noarch::flask-2.0.2-pyhd3eb1b0_0
#   flask-compress     plotly/noarch::flask-compress-1.4.0-py_0
#   itsdangerous       pkgs/main/noarch::itsdangerous-2.0.1-pyhd3eb1b0_0
#   jupyter-dash       plotly/noarch::jupyter-dash-0.3.0-py_0
#
#
#
# Downloading and Extracting Packages
# itsdangerous-2.0.1   | 18 KB     | ##################################### | 100%
# dash-table-3.6.0     | 410 KB    | ##################################### | 100%
# flask-2.0.2          | 78 KB     | ##################################### | 100%
# dash-html-components | 345 KB    | ##################################### | 100%
# dash-0.39.0          | 39 KB     | ##################################### | 100%
# dash-renderer-0.20.0 | 743 KB    | ##################################### | 100%
# dash-core-components | 3.4 MB    | ##################################### | 100%
# jupyter-dash-0.3.0   | 49 KB     | ##################################### | 100%
# ansi2html-1.5.2      | 265 KB    | ##################################### | 100%
# flask-compress-1.4.0 | 6 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from jupyter_dash import JupyterDash

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update

# %%
# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update


# Create a dash application
app = dash.Dash(__name__)

# REVIEW1: Clear the layout and do not display exception till callback gets executed
app.config.suppress_callback_exceptions = True

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})


# List of years 
year_list = [i for i in range(2005, 2021, 1)]

"""Compute graph data for creating yearly airline performance report 
Function that takes airline data as input and create 5 dataframes based on the grouping condition to be used for plottling charts and grphs.
Argument:
     
    df: Filtered dataframe
    
Returns:
   Dataframes to create graph. 
"""
def compute_data_choice_1(df):
    # Cancellation Category Count
    bar_data = df.groupby(['Month','CancellationCode'])['Flights'].sum().reset_index()
    # Average flight time by reporting airline
    line_data = df.groupby(['Month','Reporting_Airline'])['AirTime'].mean().reset_index()
    # Diverted Airport Landings
    div_data = df[df['DivAirportLandings'] != 0.0]
    # Source state count
    map_data = df.groupby(['OriginState'])['Flights'].sum().reset_index()
    # Destination state count
    tree_data = df.groupby(['DestState', 'Reporting_Airline'])['Flights'].sum().reset_index()
    return bar_data, line_data, div_data, map_data, tree_data


"""Compute graph data for creating yearly airline delay report
This function takes in airline data and selected year as an input and performs computation for creating charts and plots.
Arguments:
    df: Input airline data.
    
Returns:
    Computed average dataframes for carrier delay, weather delay, NAS delay, security delay, and late aircraft delay.
"""
def compute_data_choice_2(df):
    # Compute delay averages
    avg_car = df.groupby(['Month','Reporting_Airline'])['CarrierDelay'].mean().reset_index()
    avg_weather = df.groupby(['Month','Reporting_Airline'])['WeatherDelay'].mean().reset_index()
    avg_NAS = df.groupby(['Month','Reporting_Airline'])['NASDelay'].mean().reset_index()
    avg_sec = df.groupby(['Month','Reporting_Airline'])['SecurityDelay'].mean().reset_index()
    avg_late = df.groupby(['Month','Reporting_Airline'])['LateAircraftDelay'].mean().reset_index()
    return avg_car, avg_weather, avg_NAS, avg_sec, avg_late


# Application layout
app.layout = html.Div(children=[ 
                                # TASK1: Add title to the dashboard
                                # Enter your code below. Make sure you have correct formatting.
                                html.H1('US Domestic Airline Flights Performance', style={'textAlign':'center', 'color':'#503D36', 'font-size': 24}),
                                # REVIEW2: Dropdown creation
                                # Create an outer division 
                                html.Div([
                                    # Add an division
                                    html.Div([
                                        # Create an division for adding dropdown helper text for report type
                                        html.Div(
                                            [
                                            html.H2('Report Type:', style={'margin-right': '2em'}),
                                            ]
                                        ),
                                        # TASK2: Add a dropdown
                                        # Enter your code below. Make sure you have correct formatting.
                                        dcc.Dropdown(id='input-type', 
                                                    options=[
                                                            {'label': 'Yearly Airline Performance Report', 'value': 'OPT1'},
                                                            {'label': 'Yearly Airline Delay Report', 'value': 'OPT2'}],
                                                    placeholder='Select a report type',
                                                    style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}),
                                    # Place them next to each other using the division style
                                    ], style={'display':'flex'}),
                                    
                                   # Add next division 
                                   html.Div([
                                       # Create an division for adding dropdown helper text for choosing year
                                        html.Div(
                                            [
                                            html.H2('Choose Year:', style={'margin-right': '2em'})
                                            ]
                                        ),
                                        dcc.Dropdown(id='input-year', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': i, 'value': i} for i in year_list],
                                                     placeholder="Select a year",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}),
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}),  
                                          ]),
                                
                                # Add Computed graphs
                                # REVIEW3: Observe how we add an empty division and providing an id that will be updated during callback
                                html.Div([ ], id='plot1'),
    
                                html.Div([
                                        html.Div([ ], id='plot2'),
                                        html.Div([ ], id='plot3')
                                ], style={'display': 'flex'}),
                                
                                # TASK3: Add a division with two empty divisions inside. See above disvision for example.
                                # Enter your code below. Make sure you have correct formatting.
                                html.Div([
                                        html.Div([ ], id='plot4'),
                                        html.Div([ ], id='plot5')
                                ], style={'display': 'flex'}),
                                ])

# Callback function definition
# TASK4: Add 5 ouput components
# Enter your code below. Make sure you have correct formatting.
@app.callback( [Output(component_id='plot1', component_property='children'),
                Output(component_id='plot2', component_property='children'),
                Output(component_id='plot3', component_property='children'),
                Output(component_id='plot4', component_property='children'),
                Output(component_id='plot5', component_property='children')],
               [Input(component_id='input-type', component_property='value'),
                Input(component_id='input-year', component_property='value')],
               # REVIEW4: Holding output state till user enters all the form information. In this case, it will be chart type and year
               [State("plot1", 'children'), State("plot2", "children"),
                State("plot3", "children"), State("plot4", "children"),
                State("plot5", "children")
               ])
# Add computation to callback function and return graph
def get_graph(chart, year, children1, children2, c3, c4, c5):
      
        # Select data
        df =  airline_data[airline_data['Year']==int(year)]
       
        if chart == 'OPT1':
            # Compute required information for creating graph from the data
            bar_data, line_data, div_data, map_data, tree_data = compute_data_choice_1(df)
            
            # Number of flights under different cancellation categories
            bar_fig = px.bar(bar_data, x='Month', y='Flights', color='CancellationCode', title='Monthly Flight Cancellation')
            
            # TASK5: Average flight time by reporting airline
            # Enter your code below. Make sure you have correct formatting.
            line_fig = px.line(line_data, x='Month', y='AirTime', color='Reporting_Airline', title='Average monthly flight time (minutes) by airline')
            
            # Percentage of diverted airport landings per reporting airline
            pie_fig = px.pie(div_data, values='Flights', names='Reporting_Airline', title='% of flights by reporting airline')
            
            # REVIEW5: Number of flights flying from each state using choropleth
            map_fig = px.choropleth(map_data,  # Input data
                    locations='OriginState', 
                    color='Flights',  
                    hover_data=['OriginState', 'Flights'], 
                    locationmode = 'USA-states', # Set to plot as US States
                    color_continuous_scale='GnBu',
                    range_color=[0, map_data['Flights'].max()]) 
            map_fig.update_layout(
                    title_text = 'Number of flights from origin state', 
                    geo_scope='usa') # Plot only the USA instead of globe
            
            # TASK6: Number of flights flying to each state from each reporting airline
            # Enter your code below. Make sure you have correct formatting.
            tree_fig = px.treemap(tree_data, 
                        path=['DestState', 'Reporting_Airline'], 
                        values= 'Flights', 
                        color='Flights', 
                        color_continuous_scale='RdBu',
                        title='Flight count by airline to destination state')
            
            
            # REVIEW6: Return dcc.Graph component to the empty division
            return [dcc.Graph(figure=tree_fig), 
                    dcc.Graph(figure=pie_fig),
                    dcc.Graph(figure=map_fig),
                    dcc.Graph(figure=bar_fig),
                    dcc.Graph(figure=line_fig)
                   ]
        else:
            # REVIEW7: This covers chart type 2 and we have completed this exercise under Flight Delay Time Statistics Dashboard section
            # Compute required information for creating graph from the data
            avg_car, avg_weather, avg_NAS, avg_sec, avg_late = compute_data_choice_2(df)
            
            # Create graph
            carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')
            weather_fig = px.line(avg_weather, x='Month', y='WeatherDelay', color='Reporting_Airline', title='Average weather delay time (minutes) by airline')
            nas_fig = px.line(avg_NAS, x='Month', y='NASDelay', color='Reporting_Airline', title='Average NAS delay time (minutes) by airline')
            sec_fig = px.line(avg_sec, x='Month', y='SecurityDelay', color='Reporting_Airline', title='Average security delay time (minutes) by airline')
            late_fig = px.line(avg_late, x='Month', y='LateAircraftDelay', color='Reporting_Airline', title='Average late aircraft delay time (minutes) by airline')
            
            return[dcc.Graph(figure=carrier_fig), 
                   dcc.Graph(figure=weather_fig), 
                   dcc.Graph(figure=nas_fig), 
                   dcc.Graph(figure=sec_fig), 
                   dcc.Graph(figure=late_fig)]


# Run the app
if __name__ == '__main__':
    app.run_server(mode="inline", host="localhost", debug=False, dev_tools_ui=False, dev_tools_props_check=False)
